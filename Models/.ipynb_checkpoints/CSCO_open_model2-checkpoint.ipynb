# %%
#Dependencies
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from numpy import array
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
CSCO = pd.read_csv("CSCO.csv")
CSCO
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-11-13  33.860001  34.209999  33.830002  33.950001  30.978666
# 1    2017-11-14  33.860001  34.160000  33.799999  34.040001  31.060797
# 2    2017-11-15  33.970001  34.310001  33.750000  34.110001  31.124666
# 3    2017-11-16  36.040001  36.669998  35.830002  35.880001  32.739746
# 4    2017-11-17  35.900002  36.320000  35.810001  35.900002  32.758003
# ..          ...        ...        ...        ...        ...        ...
# 750  2020-11-05  37.020000  37.299999  36.910000  37.230000  37.230000
# 751  2020-11-06  37.560001  37.599998  37.080002  37.529999  37.529999
# 752  2020-11-09  39.919998  40.230000  38.119999  38.200001  38.200001
# 753  2020-11-10  38.209999  39.029999  38.169998  38.720001  38.720001
# 754  2020-11-11  39.009998  39.450001  38.439999  39.330002  39.330002
#
#        Volume
# 0    16441500
# 1    17468500
# 2    30829600
# 3    61177100
# 4    27988000
# ..        ...
# ...

# %%
#Shape Data
CSCO_open = CSCO['Open'].to_numpy()
X = CSCO_open.reshape(-1,1)
print("Open shape")
print(np.shape(X))
y = CSCO['Close'].to_numpy()
print("Close shape")
print(np.shape(y))
# Out:
# Open shape
# (755, 1)
# Close shape
# (755,)

# %%
X = X.reshape(755,1,1)
print(np.shape(X))
# Out:
# (755, 1, 1)

# %%
model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))

model.add(LSTM(units = 50))
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 10, batch_size = 32)

# %%
#Make predictions
predictions = model.predict(X)

# %%
predictions
print(np.shape(predictions))
# Out:
# (755, 1)

# %%
predicted_closes = np.squeeze(predictions)
print(np.shape(predicted_closes))
# Out:
# (755,)

# %%
predicted_closes = predicted_closes.tolist()
predicted_closes
# Out:
# [31.665809631347656,
#  31.665809631347656,
#  31.667598724365234,
#  31.696090698242188,
#  31.694438934326172,
#  31.694795608520508,
#  31.703922271728516,
#  31.703401565551758,
#  31.700279235839844,
#  31.701370239257812,
#  31.706480026245117,
#  31.713581085205078,
#  31.71240997314453,
#  31.707378387451172,
#  31.714115142822266,
#  31.71349334716797,
#  31.7100887298584,
#  31.70903778076172,
#  31.712135314941406,
#  31.712135314941406,
#  31.713937759399414,
#  31.716537475585938,
#  31.71746253967285,
#  31.71585464477539,
#  31.719741821289062,
#  31.721155166625977,
#  31.71982192993164,
#  31.722829818725586,
#  31.72005844116211,
#  31.720294952392578,
#  31.720216751098633,
#  31.721694946289062,
#  31.719179153442383,
#  31.721233367919922,
#  31.72161865234375,
#  31.72408676147461,
#  31.727596282958984,
#  31.727392196655273,
#  31.729185104370117,
#  31.72826385498047,
#  31.731399536132812,
#  31.731889724731445,
#  31.735816955566406,
#  31.735483169555664,
# ...

# %%
CSCO["Predicted Closes"]= predicted_closes
CSCO
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2017-11-13  33.860001  34.209999  33.830002  33.950001  30.978666
# 1    2017-11-14  33.860001  34.160000  33.799999  34.040001  31.060797
# 2    2017-11-15  33.970001  34.310001  33.750000  34.110001  31.124666
# 3    2017-11-16  36.040001  36.669998  35.830002  35.880001  32.739746
# 4    2017-11-17  35.900002  36.320000  35.810001  35.900002  32.758003
# ..          ...        ...        ...        ...        ...        ...
# 750  2020-11-05  37.020000  37.299999  36.910000  37.230000  37.230000
# 751  2020-11-06  37.560001  37.599998  37.080002  37.529999  37.529999
# 752  2020-11-09  39.919998  40.230000  38.119999  38.200001  38.200001
# 753  2020-11-10  38.209999  39.029999  38.169998  38.720001  38.720001
# 754  2020-11-11  39.009998  39.450001  38.439999  39.330002  39.330002
#
#        Volume  Predicted Closes
# 0    16441500         31.665810
# 1    17468500         31.665810
# ...

# %%
plt.plot(CSCO["Date"],CSCO["Close"], color = "red", label = "Real TESLA Stock Price")
plt.plot(CSCO["Date"],CSCO["Predicted Closes"], color = "blue", label = "Predicted TESLA Stock Price")
#plt.xticks(np.arange(0,459,50))
plt.title('TESLA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TESLA Stock Price')
plt.legend()
plt.show()
